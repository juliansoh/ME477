# %%
# %pip install numpy
# %pip install matplotlib
# %pip install pandas
# Out:
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# ...
#
# [notice] A new release of pip is available: 25.0.1 -> 25.2
# [notice] To update, run: pip3 install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
filename = 'data2.csv'
df = pd.read_csv(filename)

# Rename columns if needed
df.columns = ['Time', 'Vs', 'Vc','Vtheoretical ']

# Extract arrays
time = df['Time'].values
Vs = df['Vs'].values
Vc = df['Vc'].values
Vtheoretical = df['Vtheoretical '].values

# Plot
plt.figure(figsize=(10, 6))
plt.plot(time, Vs, label='Applied Voltage Vs (V)', linestyle='--')
plt.plot(time, Vc, label='Capacitor Voltage Vc (V)', linewidth=2)
plt.plot(time, Vtheoretical, label='Theoretical Voltage Vtheoretical (V)', linestyle=':', linewidth=2, color='red')
plt.xlabel('Time (s)')
plt.ylabel('Voltage (V)')
plt.title('Vs and Vc vs Time')
plt.legend()
plt.grid(True)
plt.tight_layout()
plt.show()
